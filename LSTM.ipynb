# %%
import yfinance as yf
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from datetime import datetime
from matplotlib import pyplot
import tkinter as tk
from tkinter import messagebox

# %%
# Arayüzü başlatma
root = tk.Tk()
root.title("Hisse Senedi Seçimi")
root.geometry("900x900")

# Seçilen grup ve hisse senedi değişkenleri
selected_group = None
selected_stock = None

# Hisse senedi seçim işlevi
def select_group(group):
    global selected_group
    selected_group = group
    show_stock_options()
    # Seçilen gruba göre butonları kaldırma
    button_a.config(state=tk.DISABLED)
    button_b.config(state=tk.DISABLED)

# Hisse senedi seçeneklerini gösterme işlevi
def show_stock_options():
    stock_frame = tk.Frame(root)
    stock_frame.pack(pady=10)

    stock_options = {}

    if selected_group == "A":
        stock_options = {
            "Akbank": "AKBNK.IS",
            "Aksa Enerji": "AKSEN.IS",
            "Alarko Holding": "ALARK.IS",
            "Arçelik": "ARCLK.IS",
            "ASELSAN": "ASELS.IS",
            "BIM": "BIMAS.IS",
            "Emlak Konut G.Y.O.": "EKGYO.IS",
            "ENKA": "ENKAI.IS",
            "Ereğli Demir ve Çelik": "EREGL.IS",
            "Ford Otosan": "FROTO.IS",
            "Garanti Bankası": "GARAN.IS",
            "Gübre T.A.S.": "GUBRF.IS",
            "HEKTAS": "HEKTS.IS",
            "Kardemir Karabük": "KRDMD.IS",
            "Koç Holding": "KCHOL.IS",
            "Koza Altın": "KOZAL.IS",
            "Koza Anadolu": "KOZAA.IS",
            "ODAS Elektrik": "ODAS.IS",
            "Pegasus": "PGSUS.IS",
            "Petkim": "PETKM.IS",
            "Sabanci Holding": "SAHOL.IS",
            "Sasa Polyester": "SASA.IS",
            "Türkiye Şişe Ve Cam": "SISE.IS",
            "TAV Havalimanlari": "TAVHL.IS",
            "Türk Hava Yollari": "THYAO.IS",
            "TOFAŞ": "TOASO.IS",
            "TÜPRAŞ": "TUPRS.IS",
            "Turkcell": "TCELL.IS",
            "Türkiye İş Bankası": "ISCTR.IS",
            "Yapi ve Kredi Bankasi A.S.": "YKBNK.IS"
            
            # Diğer hisse senetleri buraya eklenecek
        }
    elif selected_group == "B":
        stock_options = {
            "Akbank": "AKBNK.IS",
            "Aksa Enerji": "AKSEN.IS",
            "Alarko Holding": "ALARK.IS",
            "Arçelik": "ARCLK.IS",
            "ASELSAN": "ASELS.IS",
            "BIM": "BIMAS.IS",
            "Emlak Konut G.Y.O.": "EKGYO.IS",
            "ENKA": "ENKAI.IS",
            "Ereğli Demir ve Çelik": "EREGL.IS",
            "Ford Otosan": "FROTO.IS",
            "Garanti Bankası": "GARAN.IS",
            "Gübre T.A.S.": "GUBRF.IS",
            "HEKTAS": "HEKTS.IS",
            "Kardemir Karabük": "KRDMD.IS",
            "Koç Holding": "KCHOL.IS",
            "Koza Altın": "KOZAL.IS",
            "Koza Anadolu": "KOZAA.IS",
            "ODAS Elektrik": "ODAS.IS",
            "Pegasus": "PGSUS.IS",
            "Petkim": "PETKM.IS",
            "Sabanci Holding": "SAHOL.IS",
            "Sasa Polyester": "SASA.IS",
            "Türkiye Şişe Ve Cam": "SISE.IS",
            "TAV Havalimanlari": "TAVHL.IS",
            "Türk Hava Yollari": "THYAO.IS",
            "TOFAŞ": "TOASO.IS",
            "TÜPRAŞ": "TUPRS.IS",
            "Turkcell": "TCELL.IS",
            "Türkiye İş Bankası": "ISCTR.IS",
            "Yapi ve Kredi Bankasi A.S.": "YKBNK.IS",
            "xxx": "yyy",
            "xxx2": "yyy",
            "xxx3": "yyy",
            "xxx4": "yyy",
            "xxx5": "yyy",
            "xxx6": "yyy",
            "xxx7": "yyy",
            "xxx8": "yyy",
            "xxx9": "yyy",
            "xxx10": "yyy",
            "xxx11": "yyy",
            "xxx12": "yyy",
            "xxx13": "yyy",
            "xxx14": "yyy",
            "xxx15": "yyy",
            "xxx16": "yyy",
            "xxx17": "yyy",
            "xxx18": "yyy",
            "xxx19": "yyy",
            "xxx20": "yyy",
            "xxx21": "yyy",
            "xxx22": "yyy",
            "xxx23": "yyy",
            "xxx24": "yyy",
            "xxx25": "yyy",
            "xxx26": "yyy",
            "xxx27": "yyy",
            "xxx28": "yyy",
            "xxx29": "yyy",
            "xxx30": "yyy",
            "xxx31": "yyy",
            "xxx32": "yyy",
            "xxx33": "yyy",
            "xxx34": "yyy",
            "xxx35": "yyy",
            "xxx36": "yyy",
            "xxx37": "yyy",
            "xxx38": "yyy",
            "xxx39": "yyy",
            "xxx40": "yyy",
            "xxx41": "yyy",
            "xxx42": "yyy",
            "xxx43": "yyy",
            "xxx44": "yyy",
            "xxx45": "yyy",
            "xxx46": "yyy",
            "xxx47": "yyy",
            "xxx48": "yyy",
            "xxx49": "yyy",
            "xxx50": "yyy",
            "xxx51": "yyy",
            "xxx52": "yyy",
            "xxx53": "yyy",
            "xxx54": "yyy",
            "xxx55": "yyy",
            "xxx56": "yyy",
            "xxx57": "yyy",
            "xxx58": "yyy",
            "xxx59": "yyy",
            "xxx60": "yyy",
            "xxx61": "yyy",
            "xxx62": "yyy",
            "xxx63": "yyy",
            "xxx64": "yyy",
            "xxx65": "yyy",
            "xxx66": "yyy",
            "xxx67": "yyy",
            "xxx68": "yyy",
            "xxx69": "yyy",
            "xxx70": "yyy"
            
            # Diğer hisse senetleri buraya eklenecek
        }

    row = 0
    col = 0
    for stock_name, stock_symbol in stock_options.items():
        button = tk.Button(stock_frame, text=stock_name, command=lambda s=stock_symbol: select_stock(s), width=20, height=1)
        button.grid(row=row, column=col, padx=5, pady=5)
        col += 1
        if col == 5:
            col = 0
            row += 1

# Hisse senedi seçim işlevi
def select_stock(symbol):
    global selected_stock
    selected_stock = symbol
    messagebox.showinfo("Seçim", f"Seçilen hisse senedi: {selected_stock}")
    # Seçilen hisse senediyle işlemlere devam etmek için burada gerekli kodları ekleyebilirsiniz
    # Pencereyi kapatma
    root.destroy()
    
    
# Grup seçenekleri
group_options = {
    "A": "BIST 30",
    "B": "BIST 100"
}

# Butonları oluşturma
button_a = tk.Button(root, text=group_options["A"], command=lambda: select_group("A"), width=20, height=3)
button_a.pack(pady=10)

button_b = tk.Button(root, text=group_options["B"], command=lambda: select_group("B"), width=20, height=3)
button_b.pack(pady=10)

# Arayüzü çalıştırma
root.mainloop()

# Seçilen hisse senedini kullanma
if selected_stock:
    # Burada seçilen hisse senediyle işlemlere devam edebilirsiniz
    print("Seçilen hisse senedi:", selected_stock)
else:
    print("Hisse senedi seçilmedi.")
# Out:
# Seçilen hisse senedi: KCHOL.IS

# %%
stock_symbol = "THYAO.IS"
data = yf.download(stock_symbol, period='1y')
data_ = data.head()
values = data.values
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-06-21   50.950001   52.349998   50.250000   51.900002   51.900002
# 2022-06-22   51.549999   52.900002   51.250000   52.049999   52.049999
# 2022-06-23   52.049999   52.349998   50.549999   50.549999   50.549999
# 2022-06-24   51.000000   51.450001   48.959999   50.250000   50.250000
# 2022-06-27   49.099998   50.500000   49.080002   49.799999   49.799999
# ...                ...         ...         ...         ...         ...
# 2023-06-15  183.699997  184.500000  181.500000  183.000000  183.000000
# 2023-06-16  183.399994  186.199997  180.500000  180.699997  180.699997
# 2023-06-19  181.000000  181.800003  173.000000  174.000000  174.000000
# 2023-06-20  173.500000  174.300003  170.600006  171.399994  171.399994
# 2023-06-21  172.100006  173.800003  168.100006  169.399994  169.399994
#
#                Volume
# Date
# 2022-06-21   88236487
# 2022-06-22  100981096
# 2022-06-23   64744082
# 2022-06-24  119022605
# 2022-06-27   93449295
# ...               ...
# 2023-06-15   40673484
# 2023-06-16   46716947
# 2023-06-19   39071945
# 2023-06-20   37919228
# 2023-06-21   35136250
#
# [250 rows x 6 columns]

# %%
# plot each column
groups = [0, 1, 2, 3, 4, 5]
i = 1


pyplot.figure(figsize=(16,8))
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(data.columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()

# %%
data['Date'] = data.index
#single graph according to closure
pyplot.figure(figsize=(16,8))
pyplot.title('Fiyat Kapanış Grafiği ('+selected_stock+')',fontsize=15)
pyplot.plot(data['Close'])
pyplot.xlabel('Tarih',fontsize=15)
pyplot.ylabel('Kapanış Fiyatı ',fontsize=15)
pyplot.show()

# %%
data['Date'] = data.index
data = data[['Date', 'Close']]
data.reset_index(drop=True, inplace=True)
data
# Out:
#           Date       Close
# 0   2022-06-21   51.900002
# 1   2022-06-22   52.049999
# 2   2022-06-23   50.549999
# 3   2022-06-24   50.250000
# 4   2022-06-27   49.799999
# ..         ...         ...
# 245 2023-06-15  183.000000
# 246 2023-06-16  180.699997
# 247 2023-06-19  174.000000
# 248 2023-06-20  171.399994
# 249 2023-06-21  169.399994
#
# [250 rows x 2 columns]

# %%
values = data['Close'].values.reshape(-1,1)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(values)
# Birkaç Değere Bakalım
dataset[0:10]
# Out:
# array([[0.04171529],
#        [0.04280922],
#        [0.03186989],
#        [0.02968204],
#        [0.02640024],
#        [0.01356477],
#        [0.        ],
#        [0.00452158],
#        [0.02275378],
#        [0.01093933]], dtype=float32)

# %%
# %70 Train % 30 Test
TRAIN_SIZE = 0.70
train_size = int(len(dataset) * TRAIN_SIZE)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
print("Gün Sayıları (training set, test set): " + str((len(train), len(test))))
# Out:
# Gün Sayıları (training set, test set): (175, 75)

# %%
def create_dataset(dataset, window_size = 1):
    data_X, data_Y = [], []
    for i in range(len(dataset) - window_size - 1):
        a = dataset[i:(i + window_size), 0]
        data_X.append(a)
        data_Y.append(dataset[i + window_size, 0])
    return(np.array(data_X), np.array(data_Y))

# %%
# Verisetlerimizi Oluşturalım
window_size = 1
train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)
print("Original training data shape:")
print(train_X.shape)
# Yeni verisetinin şekline bakalım.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
print("New training data shape:")
print(train_X.shape)
print(test_X.shape)
# Out:
# Original training data shape:
# (173, 1)
# New training data shape:
# (173, 1, 1)
# (73, 1, 1)

# %%
def fit_model(train_X, train_Y, window_size=1):
    model = Sequential()
    # Modelin iki layerlı şekilde kurulacak.
    model.add(LSTM(units=100, return_sequences=True, input_shape=(train_X.shape[1], 1)))
    model.add(LSTM(units=100, dropout=0.1))
    model.add(Dense(units=1))
    model.compile(loss="mean_squared_error", optimizer="adam")
    # 100 epoch yani 100 kere verisetine bakılacak.
    history = model.fit(train_X, train_Y, epochs=100, batch_size=16, verbose=1)
    return model, history.history['loss']

# Modeli eğit ve kayıp değerlerini al
model1, loss_history = fit_model(train_X, train_Y, window_size)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 6s 5ms/step - loss: 0.1898
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1227
# Epoch 3/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0613
# Epoch 4/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0279
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0253
# Epoch 6/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0193
# Epoch 7/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0140
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0093
# Epoch 9/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0060
# Epoch 10/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 11/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 12/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 14/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 15/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 16/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 17/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 18/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 19/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 20/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 21/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 22/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 23/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 24/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 25/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 26/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 28/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 29/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 30/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 31/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 32/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 33/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 34/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 35/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 36/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 37/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 38/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 39/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 40/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 41/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 42/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 43/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 44/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 45/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 46/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 47/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6202e-04
# Epoch 48/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 49/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 50/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6177e-04
# Epoch 51/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 52/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 53/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 54/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 55/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 56/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.5745e-04
# Epoch 57/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 58/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7475e-04
# Epoch 59/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 60/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 61/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 62/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7249e-04
# Epoch 63/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 64/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 65/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 66/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2805e-04
# Epoch 67/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9537e-04
# Epoch 68/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 69/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.3231e-04
# Epoch 70/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 71/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.5189e-04
# Epoch 72/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 73/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 74/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 75/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6435e-04
# Epoch 76/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7136e-04
# Epoch 77/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.8881e-04
# Epoch 78/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 79/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 80/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.7484e-04
# Epoch 81/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 82/100
# 11/11 [==============================] - 0s 5ms/step - loss: 9.3578e-04
# Epoch 83/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 84/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9429e-04
# Epoch 85/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1955e-04
# Epoch 86/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.5720e-04
# Epoch 87/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2418e-04
# Epoch 88/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.8082e-04
# Epoch 89/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 90/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9942e-04
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.2883e-04
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 8.9201e-04
# Epoch 93/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6439e-04
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9069e-04
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 7.7681e-04
# Epoch 96/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.1591e-04
# Epoch 97/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.9615e-04
# Epoch 98/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 99/100
# 11/11 [==============================] - 0s 4ms/step - loss: 8.6073e-04
# Epoch 100/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0010

# %%
# Eğitim veri seti için kayıp değerlerini çiz
plt.figure(figsize=(10, 5))
plt.plot(loss_history)
plt.title('Eğitim Kaybı')
plt.xlabel('Epoch')
plt.ylabel('Kayıp')
plt.show()

# %%
# Tahmin ve skor hesaplama fonksiyonunu güncelle
def predict_and_score(model, X, Y):
    pred = scaler.inverse_transform(model.predict(X))
    orig_data = scaler.inverse_transform([Y])
    score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    return score, pred
rmse_test, test_predict = predict_and_score(model1, test_X, test_Y)
rmse_train, train_predict = predict_and_score(model1, train_X, train_Y)
# Out:
# 3/3 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Öğrendiklerinini tahminletip ekliyoruz.
train_predict_plot = np.empty_like(dataset)
train_predict_plot[:, :] = np.nan
train_predict_plot[window_size:len(train_predict) + window_size, :] = train_predict
# Şimdi ise testleri tahminletiyoruz.
test_predict_plot = np.empty_like(dataset)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (window_size * 2) + 1:len(dataset) - 1, :] = test_predict
# Plot'u oluşturalım.
plt.figure(figsize=(20, 10))
plt.plot(scaler.inverse_transform(dataset), label = "Gerçek Değer")
plt.plot(train_predict_plot, label = "Eğitim Verisi Tahmini")
plt.plot(test_predict_plot, label = "Test Verisi Tahmini")
plt.xlabel("Günler",fontsize=15)
plt.ylabel("Değer",fontsize=15)
plt.title(selected_stock+' Stock Price Prediction',fontsize=15)
plt.legend()
plt.show()

# %%
# Eğitim veri seti için tahminleri yap ve skoru al
print("Eğitim veri seti skoru: %.2f RMSE" % rmse_train)

# Test veri seti için tahminleri yap ve skoru al
print("Test veri seti skoru: %.2f RMSE" % rmse_test)
# Out:
# Eğitim veri seti skoru: 3.76 RMSE
# Test veri seti skoru: 4.29 RMSE

# %%
# Sonraki günün tahminini yapma
last_day = dataset[-1].reshape(1, 1, 1)
next_day_prediction = model1.predict(last_day)
next_day_prediction = scaler.inverse_transform(next_day_prediction)
x="{:.2f}".format(next_day_prediction[0][0])
print("Sonraki günün tahmini: ", x)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Sonraki günün tahmini:  168.33
