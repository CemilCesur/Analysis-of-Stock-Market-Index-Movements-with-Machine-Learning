# %%
import yfinance as yf
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional,LSTM, Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from datetime import datetime
from matplotlib import pyplot
import tkinter as tk
from tkinter import messagebox

# %%
# Arayüzü başlatma
root = tk.Tk()
root.title("Hisse Senedi Seçimi")
root.geometry("900x900")

# Seçilen grup ve hisse senedi değişkenleri
selected_group = None
selected_stock = None

# Hisse senedi seçim işlevi
def select_group(group):
    global selected_group
    selected_group = group
    show_stock_options()
    # Seçilen gruba göre butonları kaldırma
    button_a.config(state=tk.DISABLED)
    button_b.config(state=tk.DISABLED)

# Hisse senedi seçeneklerini gösterme işlevi
def show_stock_options():
    stock_frame = tk.Frame(root)
    stock_frame.pack(pady=10)

    stock_options = {}

    if selected_group == "A":
        stock_options = {
            "Akbank": "AKBNK.IS",
            "Aksa Enerji": "AKSEN.IS",
            "Alarko Holding": "ALARK.IS",
            "Arçelik": "ARCLK.IS",
            "ASELSAN": "ASELS.IS",
            "BIM": "BIMAS.IS",
            "Emlak Konut G.Y.O.": "EKGYO.IS",
            "ENKA": "ENKAI.IS",
            "Ereğli Demir ve Çelik": "EREGL.IS",
            "Ford Otosan": "FROTO.IS",
            "Garanti Bankası": "GARAN.IS",
            "Gübre T.A.S.": "GUBRF.IS",
            "HEKTAS": "HEKTS.IS",
            "Kardemir Karabük": "KRDMD.IS",
            "Koç Holding": "KCHOL.IS",
            "Koza Altın": "KOZAL.IS",
            "Koza Anadolu": "KOZAA.IS",
            "ODAS Elektrik": "ODAS.IS",
            "Pegasus": "PGSUS.IS",
            "Petkim": "PETKM.IS",
            "Sabanci Holding": "SAHOL.IS",
            "Sasa Polyester": "SASA.IS",
            "Türkiye Şişe Ve Cam": "SISE.IS",
            "TAV Havalimanlari": "TAVHL.IS",
            "Türk Hava Yollari": "THYAO.IS",
            "TOFAŞ": "TOASO.IS",
            "TÜPRAŞ": "TUPRS.IS",
            "Turkcell": "TCELL.IS",
            "Türkiye İş Bankası": "ISCTR.IS",
            "Yapi ve Kredi Bankasi A.S.": "YKBNK.IS"
            
            # Diğer hisse senetleri buraya eklenecek
        }
    elif selected_group == "B":
        stock_options = {
            "Akbank": "AKBNK.IS",
            "Aksa Enerji": "AKSEN.IS",
            "Alarko Holding": "ALARK.IS",
            "Arçelik": "ARCLK.IS",
            "ASELSAN": "ASELS.IS",
            "BIM": "BIMAS.IS",
            "Emlak Konut G.Y.O.": "EKGYO.IS",
            "ENKA": "ENKAI.IS",
            "Ereğli Demir ve Çelik": "EREGL.IS",
            "Ford Otosan": "FROTO.IS",
            "Garanti Bankası": "GARAN.IS",
            "Gübre T.A.S.": "GUBRF.IS",
            "HEKTAS": "HEKTS.IS",
            "Kardemir Karabük": "KRDMD.IS",
            "Koç Holding": "KCHOL.IS",
            "Koza Altın": "KOZAL.IS",
            "Koza Anadolu": "KOZAA.IS",
            "ODAS Elektrik": "ODAS.IS",
            "Pegasus": "PGSUS.IS",
            "Petkim": "PETKM.IS",
            "Sabanci Holding": "SAHOL.IS",
            "Sasa Polyester": "SASA.IS",
            "Türkiye Şişe Ve Cam": "SISE.IS",
            "TAV Havalimanlari": "TAVHL.IS",
            "Türk Hava Yollari": "THYAO.IS",
            "TOFAŞ": "TOASO.IS",
            "TÜPRAŞ": "TUPRS.IS",
            "Turkcell": "TCELL.IS",
            "Türkiye İş Bankası": "ISCTR.IS",
            "Yapi ve Kredi Bankasi A.S.": "YKBNK.IS",
            "xxx": "yyy",
            "xxx2": "yyy",
            "xxx3": "yyy",
            "xxx4": "yyy",
            "xxx5": "yyy",
            "xxx6": "yyy",
            "xxx7": "yyy",
            "xxx8": "yyy",
            "xxx9": "yyy",
            "xxx10": "yyy",
            "xxx11": "yyy",
            "xxx12": "yyy",
            "xxx13": "yyy",
            "xxx14": "yyy",
            "xxx15": "yyy",
            "xxx16": "yyy",
            "xxx17": "yyy",
            "xxx18": "yyy",
            "xxx19": "yyy",
            "xxx20": "yyy",
            "xxx21": "yyy",
            "xxx22": "yyy",
            "xxx23": "yyy",
            "xxx24": "yyy",
            "xxx25": "yyy",
            "xxx26": "yyy",
            "xxx27": "yyy",
            "xxx28": "yyy",
            "xxx29": "yyy",
            "xxx30": "yyy",
            "xxx31": "yyy",
            "xxx32": "yyy",
            "xxx33": "yyy",
            "xxx34": "yyy",
            "xxx35": "yyy",
            "xxx36": "yyy",
            "xxx37": "yyy",
            "xxx38": "yyy",
            "xxx39": "yyy",
            "xxx40": "yyy",
            "xxx41": "yyy",
            "xxx42": "yyy",
            "xxx43": "yyy",
            "xxx44": "yyy",
            "xxx45": "yyy",
            "xxx46": "yyy",
            "xxx47": "yyy",
            "xxx48": "yyy",
            "xxx49": "yyy",
            "xxx50": "yyy",
            "xxx51": "yyy",
            "xxx52": "yyy",
            "xxx53": "yyy",
            "xxx54": "yyy",
            "xxx55": "yyy",
            "xxx56": "yyy",
            "xxx57": "yyy",
            "xxx58": "yyy",
            "xxx59": "yyy",
            "xxx60": "yyy",
            "xxx61": "yyy",
            "xxx62": "yyy",
            "xxx63": "yyy",
            "xxx64": "yyy",
            "xxx65": "yyy",
            "xxx66": "yyy",
            "xxx67": "yyy",
            "xxx68": "yyy",
            "xxx69": "yyy",
            "xxx70": "yyy"
            
            # Diğer hisse senetleri buraya eklenecek
        }

    row = 0
    col = 0
    for stock_name, stock_symbol in stock_options.items():
        button = tk.Button(stock_frame, text=stock_name, command=lambda s=stock_symbol: select_stock(s), width=20, height=1)
        button.grid(row=row, column=col, padx=5, pady=5)
        col += 1
        if col == 5:
            col = 0
            row += 1

# Hisse senedi seçim işlevi
def select_stock(symbol):
    global selected_stock
    selected_stock = symbol
    messagebox.showinfo("Seçim", f"Seçilen hisse senedi: {selected_stock}")
    # Seçilen hisse senediyle işlemlere devam etmek için burada gerekli kodları ekleyebilirsiniz
    # Pencereyi kapatma
    root.destroy()
    
    
# Grup seçenekleri
group_options = {
    "A": "BIST 30",
    "B": "BIST 100"
}

# Butonları oluşturma
button_a = tk.Button(root, text=group_options["A"], command=lambda: select_group("A"), width=20, height=3)
button_a.pack(pady=10)

button_b = tk.Button(root, text=group_options["B"], command=lambda: select_group("B"), width=20, height=3)
button_b.pack(pady=10)

# Arayüzü çalıştırma
root.mainloop()

# Seçilen hisse senedini kullanma
if selected_stock:
    # Burada seçilen hisse senediyle işlemlere devam edebilirsiniz
    print("Seçilen hisse senedi:", selected_stock)
else:
    print("Hisse senedi seçilmedi.")
# Out:
# Seçilen hisse senedi: TOASO.IS

# %%
# Set the stock symbol and download historical data
stock_symbol = selected_stock
data = yf.download(stock_symbol, period='1y')
data_ = data.head()
values = data.values
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-06-21   66.449997   67.650002   66.150002   67.349998   65.141800
# 2022-06-22   67.000000   67.900002   66.150002   66.300003   64.126228
# 2022-06-23   66.599998   67.099998   65.300003   65.300003   63.159019
# 2022-06-24   65.500000   66.099998   65.199997   65.599998   63.449177
# 2022-06-27   64.300003   65.250000   63.599998   64.900002   62.772133
# ...                ...         ...         ...         ...         ...
# 2023-06-15  218.800003  225.300003  217.699997  224.500000  224.500000
# 2023-06-16  225.000000  229.699997  221.699997  224.000000  224.000000
# 2023-06-19  225.000000  225.199997  211.600006  212.000000  212.000000
# 2023-06-20  212.100006  216.100006  209.500000  214.300003  214.300003
# 2023-06-21  216.399994  222.100006  213.500000  214.300003  214.300003
#
#              Volume
# Date
# 2022-06-21  5218315
# 2022-06-22  6088101
# 2022-06-23  4552523
# 2022-06-24  4013444
# 2022-06-27  3390372
# ...             ...
# 2023-06-15  4731159
# 2023-06-16  4052434
# 2023-06-19  3542357
# 2023-06-20  2811374
# 2023-06-21  4056675
#
# [250 rows x 6 columns]

# %%
# plot each column
groups = [0, 1, 2, 3, 4, 5]
i = 1


pyplot.figure(figsize=(16,8))
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(data.columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()

# %%
#single graph according to closure
pyplot.figure(figsize=(16,8))
pyplot.title('Fiyat Kapanış Grafiği ('+selected_stock+')',fontsize=15)
pyplot.plot(data['Close'])
pyplot.xlabel('Tarih',fontsize=15)
pyplot.ylabel('Kapanış Fiyatı ',fontsize=15)
pyplot.show()

# %%
data['Date'] = data.index
data = data[['Date', 'Close']]
data.reset_index(drop=True, inplace=True)
data
# Out:
#           Date       Close
# 0   2022-06-21   67.349998
# 1   2022-06-22   66.300003
# 2   2022-06-23   65.300003
# 3   2022-06-24   65.599998
# 4   2022-06-27   64.900002
# ..         ...         ...
# 245 2023-06-15  224.500000
# 246 2023-06-16  224.000000
# 247 2023-06-19  212.000000
# 248 2023-06-20  214.300003
# 249 2023-06-21  214.300003
#
# [250 rows x 2 columns]

# %%
values = data['Close'].values.reshape(-1,1)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(values)
# Birkaç Değere Bakalım
dataset[0:10]
# Out:
# array([[0.042584  ],
#        [0.0365006 ],
#        [0.03070685],
#        [0.03244495],
#        [0.02838933],
#        [0.02085745],
#        [0.00579375],
#        [0.        ],
#        [0.00753185],
#        [0.01042873]], dtype=float32)

# %%
# %70 Train % 30 Test
TRAIN_SIZE = 0.70
train_size = int(len(dataset) * TRAIN_SIZE)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
print("Gün Sayıları (training set, test set): " + str((len(train), len(test))))
# Out:
# Gün Sayıları (training set, test set): (175, 75)

# %%
def create_dataset(dataset, window_size = 1):
    data_X, data_Y = [], []
    for i in range(len(dataset) - window_size - 1):
        a = dataset[i:(i + window_size), 0]
        data_X.append(a)
        data_Y.append(dataset[i + window_size, 0])
    return(np.array(data_X), np.array(data_Y))

# %%
# Verisetlerimizi Oluşturalım
window_size = 1
train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)
print("Original training data shape:")
print(train_X.shape)
# Yeni verisetinin şekline bakalım.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
print("New training data shape:")
print(train_X.shape)
print(test_X.shape)
# Out:
# Original training data shape:
# (173, 1)
# New training data shape:
# (173, 1, 1)
# (73, 1, 1)

# %%
def fit_model(train_X, train_Y, window_size = 1):
    model = Sequential()
    model.add(Bidirectional(LSTM(64, activation='tanh'),  input_shape=(train_X.shape[1], 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
   #100 epoch yani 100 kere verisetine bakılacak.
    model.fit(train_X, 
              train_Y, 
              epochs = 100, 
              batch_size = 16, 
              verbose = 1)
    
    return(model)
model1 = fit_model(train_X, train_Y, window_size)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 6s 5ms/step - loss: 0.1104
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0738
# Epoch 3/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0466
# Epoch 4/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0294
# Epoch 5/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 6/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0177
# Epoch 7/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 8/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 9/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0135
# Epoch 10/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 11/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0107
# Epoch 12/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 13/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 14/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 15/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 16/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 17/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 18/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 19/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 20/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 21/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 22/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 23/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9690e-04
# Epoch 24/100
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5709e-04
# Epoch 25/100
# 11/11 [==============================] - 0s 3ms/step - loss: 7.7297e-04
# Epoch 26/100
# 11/11 [==============================] - 0s 3ms/step - loss: 7.2255e-04
# Epoch 27/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.9373e-04
# Epoch 28/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7736e-04
# Epoch 29/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7180e-04
# Epoch 30/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6724e-04
# Epoch 31/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7140e-04
# Epoch 32/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6640e-04
# Epoch 33/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6721e-04
# Epoch 34/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6183e-04
# Epoch 35/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7539e-04
# Epoch 36/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6544e-04
# Epoch 37/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6736e-04
# Epoch 38/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6268e-04
# Epoch 39/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6346e-04
# Epoch 40/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6055e-04
# Epoch 41/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6297e-04
# Epoch 42/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6372e-04
# Epoch 43/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6181e-04
# Epoch 44/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6103e-04
# Epoch 45/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6481e-04
# Epoch 46/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6154e-04
# Epoch 47/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6140e-04
# Epoch 48/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6328e-04
# Epoch 49/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6033e-04
# Epoch 50/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6367e-04
# Epoch 51/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6161e-04
# Epoch 52/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6507e-04
# Epoch 53/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5805e-04
# Epoch 54/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6270e-04
# Epoch 55/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6523e-04
# Epoch 56/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5827e-04
# Epoch 57/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6019e-04
# Epoch 58/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5804e-04
# Epoch 59/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6443e-04
# Epoch 60/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5789e-04
# Epoch 61/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5823e-04
# Epoch 62/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5644e-04
# Epoch 63/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6291e-04
# Epoch 64/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6946e-04
# Epoch 65/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.9083e-04
# Epoch 66/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5927e-04
# Epoch 67/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6172e-04
# Epoch 68/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5392e-04
# Epoch 69/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5608e-04
# Epoch 70/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6027e-04
# Epoch 71/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6533e-04
# Epoch 72/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5311e-04
# Epoch 73/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.8132e-04
# Epoch 74/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5188e-04
# Epoch 75/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5452e-04
# Epoch 76/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5738e-04
# Epoch 77/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7107e-04
# Epoch 78/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5589e-04
# Epoch 79/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5598e-04
# Epoch 80/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6388e-04
# Epoch 81/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5278e-04
# Epoch 82/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7332e-04
# Epoch 83/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.4961e-04
# Epoch 84/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6011e-04
# Epoch 85/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6047e-04
# Epoch 86/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.4752e-04
# Epoch 87/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5736e-04
# Epoch 88/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6593e-04
# Epoch 89/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5538e-04
# Epoch 90/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5757e-04
# Epoch 91/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.9929e-04
# Epoch 92/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.9926e-04
# Epoch 93/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.4468e-04
# Epoch 94/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7135e-04
# Epoch 95/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.6251e-04
# Epoch 96/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5845e-04
# Epoch 97/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.4859e-04
# Epoch 98/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.7571e-04
# Epoch 99/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.8444e-04
# Epoch 100/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.4731e-04

# %%
def predict_and_score(model, X, Y):
    # Şimdi tahminleri 0-1 ile scale edilmiş halinden geri çeviriyoruz.
    pred = scaler.inverse_transform(model.predict(X))
    orig_data = scaler.inverse_transform([Y])
    # Rmse değerlerini ölçüyoruz.
    score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    return(score, pred)
rmse_train, train_predict = predict_and_score(model1, train_X, train_Y)
rmse_test, test_predict = predict_and_score(model1, test_X, test_Y)
# Out:
# 6/6 [==============================] - 1s 2ms/step
# 3/3 [==============================] - 0s 2ms/step

# %%
# Öğrendiklerinini tahminletip ekliyoruz.
train_predict_plot = np.empty_like(dataset)
train_predict_plot[:, :] = np.nan
train_predict_plot[window_size:len(train_predict) + window_size, :] = train_predict
# Şimdi ise testleri tahminletiyoruz.
test_predict_plot = np.empty_like(dataset)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (window_size * 2) + 1:len(dataset) - 1, :] = test_predict
# Plot'u oluşturalım.
plt.figure(figsize = (15, 5))
plt.plot(scaler.inverse_transform(dataset), label = "Gerçek Değer")
plt.plot(train_predict_plot, label = "Eğitim Verisi Tahmini")
plt.plot(test_predict_plot, label = "Test Verisi Tahmini")
plt.xlabel("Günler")
plt.ylabel("Değer")
plt.title("Karşılaştırma Grafiği")
plt.legend()
plt.show()

# %%
print("Training data score: %.2f RMSE" % rmse_train)
print("Test data score: %.2f RMSE" % rmse_test)
# Out:
# Training data score: 4.42 RMSE
# Test data score: 7.18 RMSE

# %%
# Sonraki günün tahminini yapma
last_day = dataset[-1].reshape(1, 1, 1)
next_day_prediction = model1.predict(last_day)
next_day_prediction = scaler.inverse_transform(next_day_prediction)
x="{:.2f}".format(next_day_prediction[0][0])
print("Sonraki günün tahmini: ", x)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Sonraki günün tahmini:  217.52
